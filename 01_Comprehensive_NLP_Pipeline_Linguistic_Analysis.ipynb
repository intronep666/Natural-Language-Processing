# %%
# Practical no 1 : Comprehensive NLP Pipeline for Linguistic Analysis Using spaCy and NLTK
import spacy
import nltk
from nltk.stem import PorterStemmer

# %%
nlp = spacy.load("en_core_web_sm")
nltk.download('punkt')
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = ("On May 13, 2025, at 6:19 p.m., the Israeli Air Force executed precision strikes on the courtyard and surrounding areas of Gaza's European Hospital in Khan Yunis, dropping at least nine bunker-busting bombs among dozens of other munitions. The attack disabled key hospital functions and struck nearby infrastructure, with the strikes guided by intelligence from the IDF, Southern Command, and Shin Bet, under real-time oversight from the IDF Chief of the General Staff.")

# %%
# Process text
doc = nlp(text)

# %%
# 1. Tokenization
print("1 Tokens:")
print([token.text for token in doc])
# Out:
# 1 Tokens:
# ['On', 'May', '13', ',', '2025', ',', 'at', '6:19', 'p.m.', ',', 'the', 'Israeli', 'Air', 'Force', 'executed', 'precision', 'strikes', 'on', 'the', 'courtyard', 'and', 'surrounding', 'areas', 'of', 'Gaza', "'s", 'European', 'Hospital', 'in', 'Khan', 'Yunis', ',', 'dropping', 'at', 'least', 'nine', 'bunker', '-', 'busting', 'bombs', 'among', 'dozens', 'of', 'other', 'munitions', '.', 'The', 'attack', 'disabled', 'key', 'hospital', 'functions', 'and', 'struck', 'nearby', 'infrastructure', ',', 'with', 'the', 'strikes', 'guided', 'by', 'intelligence', 'from', 'the', 'IDF', ',', 'Southern', 'Command', ',', 'and', 'Shin', 'Bet', ',', 'under', 'real', '-', 'time', 'oversight', 'from', 'the', 'IDF', 'Chief', 'of', 'the', 'General', 'Staff', '.']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

print("\n Stemming:")
for token in filtered_tokens:
    print(f"{token:50} -> {stemmer.stem(token)}")
# Out:
#  Stemming:
# Israeli                                            -> isra
# Air                                                -> air
# Force                                              -> forc
# executed                                           -> execut
# precision                                          -> precis
# strikes                                            -> strike
# courtyard                                          -> courtyard
# surrounding                                        -> surround
# areas                                              -> area
# Gaza                                               -> gaza
# European                                           -> european
# Hospital                                           -> hospit
# Khan                                               -> khan
# Yunis                                              -> yuni
# dropping                                           -> drop
# bunker                                             -> bunker
# busting                                            -> bust
# bombs                                              -> bomb
# dozens                                             -> dozen
# munitions                                          -> munit
# attack                                             -> attack
# disabled                                           -> disabl
# key                                                -> key
# hospital                                           -> hospit
# functions                                          -> function
# struck                                             -> struck
# nearby                                             -> nearbi
# infrastructure                                     -> infrastructur
# strikes                                            -> strike
# guided                                             -> guid
# intelligence                                       -> intellig
# IDF                                                -> idf
# Southern                                           -> southern
# Command                                            -> command
# Shin                                               -> shin
# Bet                                                -> bet
# real                                               -> real
# time                                               -> time
# oversight                                          -> oversight
# IDF                                                -> idf
# Chief                                              -> chief
# General                                            -> gener
# Staff                                              -> staff

# %%
print("\n4 Lemmatization:")
for token in doc:
    print(f"{token.text:20} ➤ {token.lemma_}")
# Out:
# 4 Lemmatization:
# On                   ➤ on
# May                  ➤ May
# 13                   ➤ 13
# ,                    ➤ ,
# 2025                 ➤ 2025
# ,                    ➤ ,
# at                   ➤ at
# 6:19                 ➤ 6:19
# p.m.                 ➤ p.m.
# ,                    ➤ ,
# the                  ➤ the
# Israeli              ➤ israeli
# Air                  ➤ Air
# Force                ➤ Force
# executed             ➤ execute
# precision            ➤ precision
# strikes              ➤ strike
# on                   ➤ on
# the                  ➤ the
# courtyard            ➤ courtyard
# and                  ➤ and
# surrounding          ➤ surround
# areas                ➤ area
# of                   ➤ of
# Gaza                 ➤ Gaza
# 's                   ➤ 's
# European             ➤ European
# Hospital             ➤ Hospital
# in                   ➤ in
# Khan                 ➤ Khan
# Yunis                ➤ Yunis
# ,                    ➤ ,
# dropping             ➤ drop
# at                   ➤ at
# least                ➤ least
# nine                 ➤ nine
# bunker               ➤ bunker
# -                    ➤ -
# busting              ➤ bust
# bombs                ➤ bomb
# among                ➤ among
# dozens               ➤ dozen
# of                   ➤ of
# other                ➤ other
# munitions            ➤ munition
# .                    ➤ .
# The                  ➤ the
# attack               ➤ attack
# disabled             ➤ disable
# key                  ➤ key
# hospital             ➤ hospital
# functions            ➤ function
# and                  ➤ and
# struck               ➤ strike
# nearby               ➤ nearby
# infrastructure       ➤ infrastructure
# ,                    ➤ ,
# with                 ➤ with
# the                  ➤ the
# strikes              ➤ strike
# guided               ➤ guide
# by                   ➤ by
# intelligence         ➤ intelligence
# from                 ➤ from
# the                  ➤ the
# IDF                  ➤ IDF
# ,                    ➤ ,
# Southern             ➤ Southern
# Command              ➤ Command
# ,                    ➤ ,
# and                  ➤ and
# Shin                 ➤ Shin
# Bet                  ➤ Bet
# ,                    ➤ ,
# under                ➤ under
# real                 ➤ real
# -                    ➤ -
# time                 ➤ time
# oversight            ➤ oversight
# from                 ➤ from
# the                  ➤ the
# IDF                  ➤ IDF
# Chief                ➤ Chief
# of                   ➤ of
# the                  ➤ the
# General              ➤ General
# Staff                ➤ Staff
# .                    ➤ .

# %%
filtered_tokens = [token.text for token in doc if not token.is_stop and token.is_alpha]
print("\n  Tokens after Stopword Removal:")
print(filtered_tokens)
# Out:
#   Tokens after Stopword Removal:
# ['Israeli', 'Air', 'Force', 'executed', 'precision', 'strikes', 'courtyard', 'surrounding', 'areas', 'Gaza', 'European', 'Hospital', 'Khan', 'Yunis', 'dropping', 'bunker', 'busting', 'bombs', 'dozens', 'munitions', 'attack', 'disabled', 'key', 'hospital', 'functions', 'struck', 'nearby', 'infrastructure', 'strikes', 'guided', 'intelligence', 'IDF', 'Southern', 'Command', 'Shin', 'Bet', 'real', 'time', 'oversight', 'IDF', 'Chief', 'General', 'Staff']

# %%
print("\n POS Tagging:")
for token in doc:
    print(f"{token.text:20} ➤ {token.pos_:10} ➤ {token.tag_}")
# Out:
#  POS Tagging:
# On                   ➤ ADP        ➤ IN
# May                  ➤ PROPN      ➤ NNP
# 13                   ➤ NUM        ➤ CD
# ,                    ➤ PUNCT      ➤ ,
# 2025                 ➤ NUM        ➤ CD
# ,                    ➤ PUNCT      ➤ ,
# at                   ➤ ADP        ➤ IN
# 6:19                 ➤ NUM        ➤ CD
# p.m.                 ➤ NOUN       ➤ NN
# ,                    ➤ PUNCT      ➤ ,
# the                  ➤ DET        ➤ DT
# Israeli              ➤ ADJ        ➤ JJ
# Air                  ➤ PROPN      ➤ NNP
# Force                ➤ PROPN      ➤ NNP
# executed             ➤ VERB       ➤ VBD
# precision            ➤ NOUN       ➤ NN
# strikes              ➤ NOUN       ➤ NNS
# on                   ➤ ADP        ➤ IN
# the                  ➤ DET        ➤ DT
# courtyard            ➤ NOUN       ➤ NN
# and                  ➤ CCONJ      ➤ CC
# surrounding          ➤ VERB       ➤ VBG
# areas                ➤ NOUN       ➤ NNS
# of                   ➤ ADP        ➤ IN
# Gaza                 ➤ PROPN      ➤ NNP
# 's                   ➤ PART       ➤ POS
# European             ➤ PROPN      ➤ NNP
# Hospital             ➤ PROPN      ➤ NNP
# in                   ➤ ADP        ➤ IN
# Khan                 ➤ PROPN      ➤ NNP
# Yunis                ➤ PROPN      ➤ NNP
# ,                    ➤ PUNCT      ➤ ,
# dropping             ➤ VERB       ➤ VBG
# at                   ➤ ADP        ➤ IN
# least                ➤ ADV        ➤ RBS
# nine                 ➤ NUM        ➤ CD
# bunker               ➤ NOUN       ➤ NN
# -                    ➤ PUNCT      ➤ HYPH
# busting              ➤ VERB       ➤ VBG
# bombs                ➤ NOUN       ➤ NNS
# among                ➤ ADP        ➤ IN
# dozens               ➤ NOUN       ➤ NNS
# of                   ➤ ADP        ➤ IN
# other                ➤ ADJ        ➤ JJ
# munitions            ➤ NOUN       ➤ NNS
# .                    ➤ PUNCT      ➤ .
# The                  ➤ DET        ➤ DT
# attack               ➤ NOUN       ➤ NN
# disabled             ➤ VERB       ➤ VBD
# key                  ➤ ADJ        ➤ JJ
# hospital             ➤ NOUN       ➤ NN
# functions            ➤ NOUN       ➤ NNS
# and                  ➤ CCONJ      ➤ CC
# struck               ➤ VERB       ➤ VBD
# nearby               ➤ ADJ        ➤ JJ
# infrastructure       ➤ NOUN       ➤ NN
# ,                    ➤ PUNCT      ➤ ,
# with                 ➤ ADP        ➤ IN
# the                  ➤ DET        ➤ DT
# strikes              ➤ NOUN       ➤ NNS
# guided               ➤ VERB       ➤ VBN
# by                   ➤ ADP        ➤ IN
# intelligence         ➤ NOUN       ➤ NN
# from                 ➤ ADP        ➤ IN
# the                  ➤ DET        ➤ DT
# IDF                  ➤ PROPN      ➤ NNP
# ,                    ➤ PUNCT      ➤ ,
# Southern             ➤ PROPN      ➤ NNP
# Command              ➤ PROPN      ➤ NNP
# ,                    ➤ PUNCT      ➤ ,
# and                  ➤ CCONJ      ➤ CC
# Shin                 ➤ PROPN      ➤ NNP
# Bet                  ➤ PROPN      ➤ NNP
# ,                    ➤ PUNCT      ➤ ,
# under                ➤ ADP        ➤ IN
# real                 ➤ ADJ        ➤ JJ
# -                    ➤ PUNCT      ➤ HYPH
# time                 ➤ NOUN       ➤ NN
# oversight            ➤ NOUN       ➤ NN
# from                 ➤ ADP        ➤ IN
# the                  ➤ DET        ➤ DT
# IDF                  ➤ PROPN      ➤ NNP
# Chief                ➤ PROPN      ➤ NNP
# of                   ➤ ADP        ➤ IN
# the                  ➤ DET        ➤ DT
# General              ➤ PROPN      ➤ NNP
# Staff                ➤ PROPN      ➤ NNP
# .                    ➤ PUNCT      ➤ .

# %%
print("\n Noun Phrase Chunks:")
for chunk in doc.noun_chunks:
    print(f"• {chunk.text}")
# Out:
#  Noun Phrase Chunks:
# • May
# • 6:19 p.m.
# • the Israeli Air Force
# • precision strikes
# • the courtyard and surrounding areas
# • Gaza's European Hospital
# • Khan Yunis
# • at least nine bunker-busting bombs
# • dozens
# • other munitions
# • The attack
# • key hospital functions
# • nearby infrastructure
# • the strikes
# • intelligence
# • the IDF
# • Southern Command
# • Shin Bet
# • real-time oversight
# • the IDF Chief
# • the General Staff

# %%
print("\n Syntax (Dependency Parsing):")
for token in doc:
    print(f"{token.text:20} ➤ {token.dep_:15} ➤ Head: {token.head.text}")
# Out:
#  Syntax (Dependency Parsing):
# On                   ➤ prep            ➤ Head: executed
# May                  ➤ pobj            ➤ Head: On
# 13                   ➤ nummod          ➤ Head: May
# ,                    ➤ punct           ➤ Head: May
# 2025                 ➤ nummod          ➤ Head: May
# ,                    ➤ punct           ➤ Head: executed
# at                   ➤ prep            ➤ Head: executed
# 6:19                 ➤ nummod          ➤ Head: p.m.
# p.m.                 ➤ pobj            ➤ Head: at
# ,                    ➤ punct           ➤ Head: executed
# the                  ➤ det             ➤ Head: Force
# Israeli              ➤ compound        ➤ Head: Force
# Air                  ➤ compound        ➤ Head: Force
# Force                ➤ nsubj           ➤ Head: executed
# executed             ➤ ROOT            ➤ Head: executed
# precision            ➤ compound        ➤ Head: strikes
# strikes              ➤ dobj            ➤ Head: executed
# on                   ➤ prep            ➤ Head: strikes
# the                  ➤ det             ➤ Head: courtyard
# courtyard            ➤ nmod            ➤ Head: areas
# and                  ➤ cc              ➤ Head: courtyard
# surrounding          ➤ amod            ➤ Head: areas
# areas                ➤ pobj            ➤ Head: on
# of                   ➤ prep            ➤ Head: areas
# Gaza                 ➤ poss            ➤ Head: Hospital
# 's                   ➤ case            ➤ Head: Gaza
# European             ➤ compound        ➤ Head: Hospital
# Hospital             ➤ pobj            ➤ Head: of
# in                   ➤ prep            ➤ Head: Hospital
# Khan                 ➤ compound        ➤ Head: Yunis
# Yunis                ➤ pobj            ➤ Head: in
# ,                    ➤ punct           ➤ Head: executed
# dropping             ➤ advcl           ➤ Head: executed
# at                   ➤ advmod          ➤ Head: least
# least                ➤ advmod          ➤ Head: nine
# nine                 ➤ nummod          ➤ Head: bombs
# bunker               ➤ npadvmod        ➤ Head: busting
# -                    ➤ punct           ➤ Head: busting
# busting              ➤ amod            ➤ Head: bombs
# bombs                ➤ dobj            ➤ Head: dropping
# among                ➤ prep            ➤ Head: dropping
# dozens               ➤ pobj            ➤ Head: among
# of                   ➤ prep            ➤ Head: dozens
# other                ➤ amod            ➤ Head: munitions
# munitions            ➤ pobj            ➤ Head: of
# .                    ➤ punct           ➤ Head: executed
# The                  ➤ det             ➤ Head: attack
# attack               ➤ nsubj           ➤ Head: disabled
# disabled             ➤ ROOT            ➤ Head: disabled
# key                  ➤ amod            ➤ Head: functions
# hospital             ➤ compound        ➤ Head: functions
# functions            ➤ dobj            ➤ Head: disabled
# and                  ➤ cc              ➤ Head: disabled
# struck               ➤ conj            ➤ Head: disabled
# nearby               ➤ amod            ➤ Head: infrastructure
# infrastructure       ➤ dobj            ➤ Head: struck
# ,                    ➤ punct           ➤ Head: struck
# with                 ➤ prep            ➤ Head: struck
# the                  ➤ det             ➤ Head: strikes
# strikes              ➤ pobj            ➤ Head: with
# guided               ➤ acl             ➤ Head: strikes
# by                   ➤ agent           ➤ Head: guided
# intelligence         ➤ pobj            ➤ Head: by
# from                 ➤ prep            ➤ Head: intelligence
# the                  ➤ det             ➤ Head: IDF
# IDF                  ➤ pobj            ➤ Head: from
# ,                    ➤ punct           ➤ Head: IDF
# Southern             ➤ compound        ➤ Head: Command
# Command              ➤ conj            ➤ Head: IDF
# ,                    ➤ punct           ➤ Head: disabled
# and                  ➤ cc              ➤ Head: disabled
# Shin                 ➤ compound        ➤ Head: Bet
# Bet                  ➤ conj            ➤ Head: disabled
# ,                    ➤ punct           ➤ Head: Bet
# under                ➤ prep            ➤ Head: disabled
# real                 ➤ amod            ➤ Head: time
# -                    ➤ punct           ➤ Head: time
# time                 ➤ compound        ➤ Head: oversight
# oversight            ➤ pobj            ➤ Head: under
# from                 ➤ prep            ➤ Head: oversight
# the                  ➤ det             ➤ Head: Chief
# IDF                  ➤ compound        ➤ Head: Chief
# Chief                ➤ pobj            ➤ Head: from
# of                   ➤ prep            ➤ Head: Chief
# the                  ➤ det             ➤ Head: Staff
# General              ➤ compound        ➤ Head: Staff
# Staff                ➤ pobj            ➤ Head: of
# .                    ➤ punct           ➤ Head: disabled

# %%
# 8. Semantics: Named Entity Recognition
print("\n Named Entities:")
for ent in doc.ents:
    print(f"{ent.text:40} ➤ {ent.label_}")
# Out:
#  Named Entities:
# May 13, 2025                             ➤ DATE
# 6:19 p.m.                                ➤ TIME
# the Israeli Air Force                    ➤ ORG
# Gaza                                     ➤ GPE
# European Hospital                        ➤ ORG
# Khan Yunis                               ➤ GPE
# at least nine                            ➤ CARDINAL
# dozens                                   ➤ CARDINAL
# IDF                                      ➤ ORG
# Southern Command                         ➤ ORG
# Shin Bet                                 ➤ PERSON
# IDF                                      ➤ ORG
